# %%
import pandas as pd


df_no_outliers = pd.read_csv("C:/Users/Zainab/Downloads/swimming_data_no_outliers.csv")

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np


# Ensure Ranking is numeric
df_no_outliers['Ranking_numeric'] = pd.to_numeric(df_no_outliers['Ranking'], errors='coerce')
df_no_outliers = df_no_outliers.dropna(subset=['Ranking_numeric'])

# Define features and target
features = ['Ranking_numeric', 'Distance', 'Sex', 'Event']
target = 'Time_seconds'

X_no = df_no_outliers[features]
y_no = df_no_outliers[target]

# Split into training and testing sets (80/20 split)
X_train_no, X_test_no, y_train_no, y_test_no = train_test_split(X_no, y_no, test_size=0.2, random_state=42)

# Define numeric and categorical features 
numeric_features = ['Ranking_numeric', 'Distance']
categorical_features = ['Sex', 'Event']

# Create the transformers for numeric and categorical data
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Combine them using a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Create an MLP pipeline.
# Here we set hidden_layer_sizes to (4,), which means one hidden layer with 4 neurons.
pipeline_mlp_no = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('mlp', MLPRegressor(hidden_layer_sizes=(4,), activation='relu', solver='adam', 
                         max_iter=500, random_state=42))
])

# Train the MLP model
pipeline_mlp_no.fit(X_train_no, y_train_no)

# Predict on the test set
y_pred_mlp_no = pipeline_mlp_no.predict(X_test_no)

# Evaluate performance: compute RMSE and R²
rmse_mlp_no = np.sqrt(mean_squared_error(y_test_no, y_pred_mlp_no))
r2_mlp_no = r2_score(y_test_no, y_pred_mlp_no)

print("MLP Neural Network Model (No Outliers) Performance:")
print("RMSE:", rmse_mlp_no)
print("R²:", r2_mlp_no)
# Out:
# MLP Neural Network Model (No Outliers) Performance:
# RMSE: 146.61414056537635
# R²: 0.5972934114878241
# C:\Users\Zainab\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (500) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np


# Ensure Ranking is numeric (if not already done) and drop any rows with missing values in that column.
df_no_outliers['Ranking_numeric'] = pd.to_numeric(df_no_outliers['Ranking'], errors='coerce')
df_no_outliers = df_no_outliers.dropna(subset=['Ranking_numeric'])

# Define features and target
features = ['Ranking_numeric', 'Distance', 'Sex', 'Event']
target = 'Time_seconds'

X_no = df_no_outliers[features]
y_no = df_no_outliers[target]

# Split into training and testing sets (80/20 split)
X_train_no, X_test_no, y_train_no, y_test_no = train_test_split(X_no, y_no, test_size=0.2, random_state=42)

# Define numeric and categorical features (same as before)
numeric_features = ['Ranking_numeric', 'Distance']
categorical_features = ['Sex', 'Event']

# Create the transformers for numeric and categorical data
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Combine them using a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Create an MLP pipeline.

# Adjusted MLP pipeline with increased iterations and a more complex network architecture
pipeline_mlp_adjusted = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('mlp', MLPRegressor(hidden_layer_sizes=(8, 4), activation='relu', solver='adam', 
                         max_iter=1000, random_state=42))
])

# Train the adjusted MLP model
pipeline_mlp_adjusted.fit(X_train_no, y_train_no)

# Predict on the test set
y_pred_mlp_adjusted = pipeline_mlp_adjusted.predict(X_test_no)


rmse_mlp_adjusted = np.sqrt(mean_squared_error(y_test_no, y_pred_mlp_adjusted))
r2_mlp_adjusted = r2_score(y_test_no, y_pred_mlp_adjusted)

print("Adjusted MLP Neural Network Model (No Outliers) Performance:")
print("RMSE:", rmse_mlp_adjusted)
print("R²:", r2_mlp_adjusted)
# Out:
# Adjusted MLP Neural Network Model (No Outliers) Performance:
# RMSE: 20.45667275471725
# R²: 0.9921601633705326
# C:\Users\Zainab\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np


# Ensure Ranking is numeric and drop any rows with missing values in that column.
df_no_outliers['Ranking_numeric'] = pd.to_numeric(df_no_outliers['Ranking'], errors='coerce')
df_no_outliers = df_no_outliers.dropna(subset=['Ranking_numeric'])

# Define features and target
features = ['Ranking_numeric', 'Distance', 'Sex', 'Event']
target = 'Time_seconds'

X_no = df_no_outliers[features]
y_no = df_no_outliers[target]

# Split into training and testing sets (80/20 split)
X_train_no, X_test_no, y_train_no, y_test_no = train_test_split(X_no, y_no, test_size=0.2, random_state=42)

# Define numeric and categorical features 
numeric_features = ['Ranking_numeric', 'Distance']
categorical_features = ['Sex', 'Event']

# Create the transformers for numeric and categorical data
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Combine them using a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Create an MLP pipeline.

pipeline_mlp_more_iter = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('mlp', MLPRegressor(hidden_layer_sizes=(8, 4), activation='relu', solver='adam', 
                         max_iter=2000, random_state=42))
])

# Train the model with increased iterations
pipeline_mlp_more_iter.fit(X_train_no, y_train_no)

# Predict on the test set
y_pred_mlp_more_iter = pipeline_mlp_more_iter.predict(X_test_no)


rmse_mlp_more_iter = np.sqrt(mean_squared_error(y_test_no, y_pred_mlp_more_iter))
r2_mlp_more_iter = r2_score(y_test_no, y_pred_mlp_more_iter)

print("MLP Neural Network Model (No Outliers) with max_iter=2000 Performance:")
print("RMSE:", rmse_mlp_more_iter)
print("R²:", r2_mlp_more_iter)
# Out:
# MLP Neural Network Model (No Outliers) with max_iter=2000 Performance:
# RMSE: 19.931027423952276
# R²: 0.9925578847633758

# %%
import matplotlib.pyplot as plt

# Scatter plot: Actual vs Predicted
plt.figure(figsize=(8, 6))
plt.scatter(y_test_no, y_pred_mlp_more_iter, alpha=0.6, edgecolors='k')
plt.plot([y_test_no.min(), y_test_no.max()], [y_test_no.min(), y_test_no.max()], 'r--', lw=2)
plt.xlabel("Actual Swimming Time (seconds)")
plt.ylabel("Predicted Swimming Time (seconds)")
plt.title("Actual vs. Predicted Swimming Times (MLP Model)")
plt.show()

# %%
# Calculate residuals
residuals = y_test_no - y_pred_mlp_more_iter

# Residual plot
plt.figure(figsize=(8, 6))
plt.scatter(y_pred_mlp_more_iter, residuals, alpha=0.6, edgecolors='k')
plt.hlines(y=0, xmin=y_pred_mlp_more_iter.min(), xmax=y_pred_mlp_more_iter.max(), colors='r', linestyles='dashed')
plt.xlabel("Predicted Swimming Time (seconds)")
plt.ylabel("Residuals (Actual - Predicted)")
plt.title("Residual Plot for MLP Model")
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.hist(residuals, bins=30, edgecolor='black', alpha=0.7)
plt.xlabel("Residuals")
plt.ylabel("Frequency")
plt.title("Histogram of Residuals (MLP Model)")
plt.show()

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import numpy as np
import pandas as pd


# Ensure 'Ranking_numeric' exists and drop rows with missing values
df_no_outliers['Ranking_numeric'] = pd.to_numeric(df_no_outliers['Ranking'], errors='coerce')
df_no_outliers = df_no_outliers.dropna(subset=['Ranking_numeric'])

# Define features and target
features = ['Ranking_numeric', 'Distance', 'Sex', 'Event']
target = 'Time_seconds'
X_no_outliers = df_no_outliers[features]
y_no_outliers = df_no_outliers[target]

# Define numeric and categorical features
numeric_features = ['Ranking_numeric', 'Distance']
categorical_features = ['Sex', 'Event']

# Create transformers
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Combine transformers into a preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Define the MLP pipeline
pipeline_mlp_more_iter = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('mlp', MLPRegressor(hidden_layer_sizes=(8, 4), activation='relu', solver='adam', 
                         max_iter=2000, random_state=42))
])

# Perform 10-fold cross-validation for the MLP model using negative MSE
cv_scores_mlp = cross_val_score(pipeline_mlp_more_iter, X_no_outliers, y_no_outliers, 
                                cv=10, scoring='neg_mean_squared_error')
# Convert negative MSE to RMSE
rmse_cv_mlp = np.sqrt(-cv_scores_mlp)
print("MLP CV RMSE: {:.2f} ± {:.2f}".format(rmse_cv_mlp.mean(), rmse_cv_mlp.std()))
# Out:
# C:\Users\Zainab\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Zainab\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Zainab\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\Zainab\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLP CV RMSE: 67.39 ± 58.51

# %%
import numpy as np
import pandas as pd
from sklearn.neural_network import MLPRegressor  
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder


# Ensure 'Ranking_numeric' exists and drop rows with missing values
df_no_outliers['Ranking_numeric'] = pd.to_numeric(df_no_outliers['Ranking'], errors='coerce')
df_no_outliers = df_no_outliers.dropna(subset=['Ranking_numeric'])

# Define features and target
features = ['Ranking_numeric', 'Distance', 'Sex', 'Event']
target = 'Time_seconds'
X_no_outliers = df_no_outliers[features]
y_no_outliers = df_no_outliers[target]

# Define which features are numeric and which are categorical
numeric_features = ['Ranking_numeric', 'Distance']
categorical_features = ['Sex', 'Event']

# Create transformers for numeric and categorical features
numeric_transformer = StandardScaler()
categorical_transformer = OneHotEncoder(handle_unknown='ignore')

# Combine transformers into a ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)
    ])

# Build the tuned MLP pipeline with increased iterations, lower tolerance, and early stopping
pipeline_mlp_tuned = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('mlp', MLPRegressor(hidden_layer_sizes=(8, 4),
                         activation='relu',
                         solver='adam',
                         max_iter=3000,       # Increased iterations
                         tol=1e-5,            
                         early_stopping=True, 
                         random_state=42))
])


pipeline_mlp_tuned.fit(X_no_outliers, y_no_outliers)


from sklearn.model_selection import cross_val_score
cv_scores_mlp = cross_val_score(pipeline_mlp_tuned, X_no_outliers, y_no_outliers, 
                                cv=10, scoring='neg_mean_squared_error')
rmse_cv_mlp = np.sqrt(-cv_scores_mlp)
print("Tuned MLP CV RMSE: {:.2f} ± {:.2f}".format(rmse_cv_mlp.mean(), rmse_cv_mlp.std()))
# Out:
# Tuned MLP CV RMSE: 61.00 ± 54.49

# %%
from sklearn.model_selection import GridSearchCV

# Define the hyperparameter grid for the MLPRegressor
param_grid = {
    'mlp__hidden_layer_sizes': [(8, 4), (10, 5), (16, 8), (32, 16)],
    'mlp__alpha': [0.0001, 0.001, 0.01],
    'mlp__learning_rate_init': [0.001, 0.01, 0.1],
    'mlp__max_iter': [2000, 3000]
}

# Set up the grid search with 5-fold cross-validation and negative MSE scoring
grid_search = GridSearchCV(pipeline_mlp_tuned, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Fit the grid search on the entire outlier-removed dataset
grid_search.fit(X_no_outliers, y_no_outliers)


print("Best Parameters:", grid_search.best_params_)
best_rmse = np.sqrt(-grid_search.best_score_)
print("Best RMSE from Grid Search:", best_rmse)
# Out:
# Best Parameters: {'mlp__alpha': 0.0001, 'mlp__hidden_layer_sizes': (8, 4), 'mlp__learning_rate_init': 0.001, 'mlp__max_iter': 2000}
# Best RMSE from Grid Search: 81.3392500925696

# %%
best_model = grid_search.best_estimator_
y_pred_tuned = best_model.predict(X_test_no)
rmse_tuned = np.sqrt(mean_squared_error(y_test_no, y_pred_tuned))
r2_tuned = r2_score(y_test_no, y_pred_tuned)
print("Tuned Model Test RMSE:", rmse_tuned)
print("Tuned Model Test R²:", r2_tuned)
# Out:
# Tuned Model Test RMSE: 21.106528713114336
# Tuned Model Test R²: 0.9916541486924433

# %%
# Compute predictions from the linear regression pipeline
df_no_outliers['Predicted_Time_LR'] = pipeline_lr_no.predict(df_no_outliers[features])
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19844\3252657368.py in <module>
#       1 # Compute predictions from the linear regression pipeline
# ----> 2 df_no_outliers['Predicted_Time_LR'] = pipeline_lr_no.predict(df_no_outliers[features])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     111
#     112             # lambda, but not partial, allows help() to work with update_wrapper
# --> 113             out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114         else:
#     115
#
# ~\anaconda3\lib\site-packages\sklearn\pipeline.py in predict(self, X, **predict_params)
#     467         Xt = X
#     468         for _, name, transform in self._iter(with_final=False):
# --> 469             Xt = transform.transform(Xt)
# ...
